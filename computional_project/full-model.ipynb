# %%
import cobra
from cobra import Model,Reaction,Metabolite
import cobra.test
import os
from os.path import join

data_dir = cobra.test.data_dir

# %%
model=Model('FULL')
#model = cobra.test.create_test_model("textbook")

# %%
########## Metabolites

accoa_c=Metabolite("accoa_c",
                 formula="C23H34N7O17P3S",
                 name="acetyl_CoA",
                 compartment="c")


oaa_c=Metabolite("oaa_c",
                 formula="C4H2O5",
                 name="oxaloacetate",
                 compartment="c")


h2o_c =Metabolite("h2o_c",
                 formula="H2O",
                 name="Water",
                 compartment="c")


cit_c=Metabolite("cit_c",
                 formula="C6H5O7",
                 name="citrate",
                 compartment="c")


coa_c=Metabolite("coa_c",
                 formula="C21H32N7O16P3S",
                 name="coenzyme",
                 compartment="c")


h_c=Metabolite("h_c",
                 formula="H",
                 name="Hydrogen",
                 compartment="c") 


acon_C_c=Metabolite("acon_C_c",
                 formula="C6H6O6",
                 name="cis_Aconitate",
                 compartment="c")


icit_c=Metabolite("icit_C",
                 formula="C6H8O7",
                 name="Isocitrate",
                 compartment="c")


nadp_c=Metabolite("nadp_c",
                 formula="C21H26N7O14P2",
                 name="Nicotinamide adenine dinucleotide phosphate",
                 compartment="c")


nadph_c=Metabolite("nadph_c",
                 formula="C21H27N7O14P2",
                 name="Nicotinamide adenine dinucleotide phosphate - reduced",
                 compartment="c")


akg_c=Metabolite("akg_c",
                 formula="C5H4O5",
                 name="2-Oxoglutarate",
                 compartment="c")  


co2_c=Metabolite("co2_c",
                 formula="CO2",
                 name="CO2",
                 compartment="c")


succoa_c=Metabolite("succoa_c",
                 formula="C25H35N7O19P3S",
                 name="Succinyl-CoA",
                 compartment="c") 


atp_c=Metabolite("atp_c",
                 formula="C10H12N5O13P3",
                 name="ATP",
                 compartment="c")


succ_c=Metabolite("succ_c",
                 formula="C4H4O4",
                 name="Succinate",
                 compartment="c")


adp_c=Metabolite("adp_c",
                 formula="C10H12N5O10P2",
                 name="ADP",
                 compartment="c")


pi_c=Metabolite("pi_c",
                 formula="HO4P",
                 name="Phosphate",
                 compartment="c")


q8_c=Metabolite("q8_c",
                 formula="C49H74O4",
                 name="Ubiquinone-8",
                 compartment="c")


q8h2_c=Metabolite("q8h2_c",
                 formula="C49H76O4",
                 name="Ubiquinol-8",
                 compartment="c")


fum_c=Metabolite("fum_C",
                 formula="C4H2O4",
                 name="fumarate",
                 compartment="c")

   
mal__L_c=Metabolite("mal__L_c",
                 formula="C4H6O5",
                 name="L-Malate",
                 compartment="c")


nad_c = Metabolite('nad_c',
                   compartment='c',
                   formula = "C21H26N7O14P2",
                   name ="Nicotinamide adenine dinucleotide")
 
    
nadh_c = Metabolite('nadh_c',
                    compartment='c',
                    formula = "C21H27N7O14P2",
                    name ="Nicotinamide adenine dinucleotide - reduced")
 
o2_c = Metabolite('o2_c' , 
                  compartment = 'c',
                  formula = "O2",
                  name ="O2 O2")


amp_c = Metabolite('amp_c' , 
                   compartment = 'c',
                   formula = "C10H12N5O7P",
                   name ="AMP C10H12N5O7P")


o2_e = Metabolite('o2_e' , 
                  compartment = 'e',
                  formula = "O2",
                  name ="O2 O2")


q8h2_c = Metabolite('q8h2_c' , 
                    compartment = 'c',
                    formula = "C49H76O4",
                    name ="Ubiquinol-8")


q8_c = Metabolite('q8_c' , 
                  compartment = 'c',
                  formula = "C49H74O4",
                  name ="Ubiquinone-8")





e4p_c = Metabolite('e4p_c' ,
                   compartment = 'c',
                   formula = "C4H7O7P",
                   name ="D-Erythrose 4-phosphate")


f6p_c = Metabolite('f6p_c' , 
                   compartment = 'c',
                   formula = "C6H11O9P",
                   name ="D-Fructose 6-phosphate")


g3p_c = Metabolite('g3p_c' , 
                   compartment = 'c',
                   formula = "C3H5O6P",
                   name ="Glyceraldehyde 3-phosphate")


g6p_c = Metabolite('g6p_c' , 
                   compartment = 'c',
                   formula = "C6H11O9P",
                   name ="D-Glucose 6-phosphate")


gln__L_c = Metabolite('gln__L_c' , 
                      compartment = 'c',
                      formula = "C5H10N2O3",
                      name ="L-Glutamine")


glu__L_c = Metabolite('glu__L_c' , 
                      compartment = 'c',
                      formula = "C5H8NO4",
                      name ="L-Glutamate")


pep_c = Metabolite('pep_c' , 
                   compartment = 'c',
                   formula = "C3H2O6P",
                   name ="Phosphoenolpyruvate")


pyr_c = Metabolite('pyr_c' , 
                   compartment = 'c',
                   formula = "C3H3O3",
                   name ="Pyruvate")


r5p_c = Metabolite('r5p_c' , 
                   compartment = 'c',
                   formula = "C5H9O8P",
                   name ="Alpha-D-Ribose 5-phosphate")


h_e = Metabolite('h_e',
                 compartment='e',
                 formula = "H",
                 name ="H+")


succ_e = Metabolite('succ_e' , 
                    compartment = 'e',
                    formula = "C4H4O4",
                    name ="Succinate")


akg_e = Metabolite('akg_e' , 
                    compartment = 'e',
                    formula = "C5H4O5",
                    name ="2-Oxoglutarate")



glu__L_e = Metabolite('glu__L_e' , 
                    compartment = 'e',
                    formula = "C5H8NO4",
                    name ="L-Glutamate")


nh4_c = Metabolite('nh4_c' , 
                    compartment = 'c',
                    formula = "H4N",
                    name ="Ammonium")


gln__L_e = Metabolite('gln__L_e' , 
                    compartment = 'e',
                    formula = "C5H10N2O3",
                    name ="L-Glutamine")


glc__D_e=Metabolite(
    'glc__D_e',
    formula='C6H12O6',
    name='Glucose',
    compartment='c')


dhap_c=Metabolite(
    'dhap_c',
    formula='C3H7O6P',
    name='Dihydroxyacetonephoshate ',
    compartment='c')  


dpg_c=Metabolite(
    '13dpg_c',
    formula='C3H6O10P2-2',
    name='1,3Diphosphoglycerate ',
    compartment='c')  


lac__D_c=Metabolite(
    'lac__D_c',
    formula='C3H6O3 ',
    name='Lactate ',
    compartment='c')  



pg3_c=Metabolite(
    '3pg_c',
    formula='C3H7O7P',
    name='3-Phosphoglycerate',
    compartment='c')


pg_c = Metabolite('3pg_c' , 
                  compartment = 'c',
                  formula = "C3H4O7P",
                  name ="3-Phospho-D-glycerate")


pg2_c=Metabolite(
    '2pg_c',
    formula='C3H7O7P',
    name='2-Phosphoglycerate',
    compartment='c')


pyr_e=Metabolite(
    'pyr_e',
    formula='C3H4O3',
    name='Pyruvate',
    compartment='e')


lac__D_e=Metabolite(
    'lac__D_e',
    formula='C3H5O3',
    name='D-Lactate',
    compartment='e')


ac_c=Metabolite(
    'ac_c',
    formula='C2H3O2',
    name='Acetate',
    compartment='c')


ac_e=Metabolite(
    'ac_e',
    formula='C2H3O2',
    name='Acetate',
    compartment='e')


pgl6_c=Metabolite(
    'pgl6_c',
    formula='C6H9O9P',
    name='6-phospho-D-glucono-1,5-lactone',
    compartment='c')


pgc6_c=Metabolite(
    'pgc6_c',
    formula='C6H10O10P',
    name='6-Phospho-D-gluconate',
    compartment='c')


ru5p__D_c=Metabolite(
    'ru5p__D_c',
    formula='C5H9O8P',
    name='D-Ribulose 5-phosphate',
    compartment='c')


xu5p__D_c=Metabolite(
    'xu5p__D_c',
    formula='C5H9O8P', 
    name='D-Xylulose 5-phosphate',
    compartment='c')

actp_c=Metabolite(
    'actp_c',
    formula='C2H3O5P',
    name='Acetyl phosphate',
    compartment='c')


s7p_c=Metabolite(
    's7p_c',
    formula='C7H13O10P',
    name='Sedoheptulose 7-phosphate' ,
    compartment='c')


fru_e=Metabolite(
    'fru_e',
    formula='C6H12O6',
    name='D-Fructose',
    compartment='e')


for_c=Metabolite(
    'for_c',
    formula='CH1O2',
    name='Formate',
    compartment='c')


for_e=Metabolite(
    'for_e',
    formula='CH1O2',
    name='Formate',
    compartment='e')


fdp_c=Metabolite(
    'fdp_c',
    formula='C6H14O12P2',
    name='Fructose1,6-diphosphate',
    compartment='c')

     
acald_c=Metabolite(
     'acald_c',
    formula='C2H4O ',
    name=' acetaldehyde  ',
    compartment='c')


acald_e=Metabolite(
     'acald_e',
    formula='C2H4O ',
    name=' acetaldehyde  ',
    compartment='e') 


etoh_c=Metabolite(
    'etoh_c',
    formula='C2H6O',
    name='ethanol',
    compartment='c')


etoh_e=Metabolite(
    'etoh_e',
    formula='C2H6O',
    name='ethanol',
    compartment='e')


glx_c=Metabolite(
    'glx_c',
    formula='C2H1O3',
    name='Glyoxylate',
    compartment='c')


pi_e=Metabolite(
    'pi_e',
    formula='HO4P',
    name='Phosphate',
    compartment='e')


h2o_e=Metabolite(
    'h2o_e',
    formula='H2O',
    name='H2O H2O',
    compartment='e')



co2_e=Metabolite(
    'co2_e',
    formula='CO2',
    name='CO2 CO2',
    compartment='e')


nh4_e=Metabolite(
    'nh4_e',
    formula='H4N',
    name='Ammonium',
    compartment='e')

# %%
#------>Reactions<-------#
  
 #1  
 # glc__D_e----->
EX_glc__D_e=Reaction('EX_glc__D_e')
EX_glc__D_e.name='D-Glucose_exchange'
EX_glc__D_e.lower_bound=-10
EX_glc__D_e.upper_bound=1000

EX_glc__D_e.add_metabolites({glc__D_e: -1})


#2
    
########## glc__D_e + pep_c ========> g6p_c  +  pyr_c   

GLCpts=Reaction('GLCpts')
GLCpts.name='D-glucose_transport_viaPEP:Pyr_PTS'
GLCpts.lower_bound=0
GLCpts.upper_bound=1000

GLCpts.add_metabolites({g6p_c: 1.0 , glc__D_e: -1.0 , pep_c: -1.0 , pyr_c: 1.0})




#3
G6PDH2r=Reaction('G6PDH2r')
G6PDH2r.name='Glucose 6-phosphate dehydrogenase '
G6PDH2r.lower_bound=-1000.0 
G6PDH2r.upper_bound= 1000.0 

G6PDH2r.add_metabolites({pgl6_c: 1.0 , g6p_c: -1.0 , h_c: 1.0 , nadp_c: -1.0 , nadph_c: 1.0})



#4
PGL=Reaction('PGL')
PGL.name='6-phosphogluconolactonase'
PGL.lower_bound=0.0 
PGL.upper_bound=1000.0 

PGL.add_metabolites({pgc6_c: 1.0 , pgl6_c: -1.0 , h2o_c: -1.0 , h_c: 1.0})


#5
GND=Reaction('GND')
GND.name='Phosphogluconate dehydrogenase'
GND.lower_bound=0.0 
GND.upper_bound=1000.0

GND.add_metabolites({pgc6_c:-1.0 , co2_c: 1.0 , nadp_c: -1.0 , nadph_c: 1.0 , ru5p__D_c: 1.0})

#6
RPE=Reaction('RPE')
RPE.name='Ribulose 5-phosphate 3-epimerase'
RPE.lower_bound=-1000.0 
RPE.upper_bound=1000.0 

RPE.add_metabolites({ru5p__D_c: -1.0 , xu5p__D_c: 1.0})


#7
RPI=Reaction('RPI')
RPI.name='Ribose-5-phosphate isomerase'
RPI.lower_bound=-1000.0 
RPI.upper_bound=1000.0 

RPI.add_metabolites({r5p_c: -1.0 , ru5p__D_c: 1.0})


#8
TKT1=Reaction('TKT1')
TKT1.name='Transketolase'
TKT1.lower_bound=-1000.0 
TKT1.upper_bound=1000.0 

TKT1.add_metabolites({g3p_c: 1.0 , r5p_c: -1.0 , s7p_c: 1.0 , xu5p__D_c: -1.0})

#9
TALA=Reaction('TALA')
TALA.name='Transaldolase'
TALA.lower_bound=-1000.0 
TALA.upper_bound=1000.0

TALA.add_metabolites({e4p_c: 1.0 , f6p_c: 1.0 , g3p_c: -1.0 , s7p_c: -1.0})


#10
TKT2=Reaction('TKT2')
TKT2.name='Transketolase'
TKT2.lower_bound=-1000.0 
TKT2.upper_bound=1000.0     
   
TKT2.add_metabolites({e4p_c: -1.0 , f6p_c: 1.0 , g3p_c: 1.0 , xu5p__D_c: -1.0})

#11
########## g6p_c <===========> f6p_c
PGI=Reaction('PGI')
PGI.name='Glucose6-phosphate isomerase '
PGI.lower_bound=-1000
PGI.upper_bound=1000

PGI.add_metabolites({g6p_c: -1 , f6p_c: 1})

#12
FRUpts2=Reaction('FRUpts2')
FRUpts2.name='FructosetransportviaPEP:PyrPTS(f6p generating)'
FRUpts2.lower_bound=0.0 
FRUpts2.upper_bound=1000.0  

FRUpts2.add_metabolites({f6p_c: 1.0 , fru_e: -1.0 , pep_c: -1.0 , pyr_c: 1.0})

#13
FBP=Reaction('FBP')
FBP.name='Fructose-bisphosphatase'
FBP.lower_bound=0.0 
FBP.upper_bound=1000.0 

FBP.add_metabolites({f6p_c: 1.0 , fdp_c: -1.0 , h2o_c: -1.0 , pi_c: 1.0})


#14
EX_fru_e=Reaction('EX_fru_e')
EX_fru_e.name='D-Fructose exchange'
EX_fru_e.lower_bound=0.0 
EX_fru_e.upper_bound=1000.0 

EX_fru_e.add_metabolites({fru_e:-1.0})


#15
PFK=Reaction('PFK')
PFK.name='Phosphofructokinase'
PFK.lower_bound=0
PFK.upper_bound=1000

PFK.add_metabolites({f6p_c:-1,atp_c:-1,fdp_c:1,adp_c:1,h_c:1})


# 16
TPI=Reaction('TPI' )
TPI.name='triose_phosphate_isomerase'
TPI.lower_bound=-1000
TPI.upper_bound=1000
 
TPI.add_metabolites({dhap_c:-1,g3p_c:1}) 
  
##17
FBA=Reaction('FBA')
FBA.name='fructose 1,6-diphosphate Adolase'
FBA.lower_bound=-1000
FBA.upper_bound=1000

FBA.add_metabolites({fdp_c:-1,dhap_c:1,g3p_c:1}) 


# 18
GAPD=Reaction('GAPD')

GAPD.name='Glyceraldehyde-3-phosphate dehydrogenase '
GAPD.lower_bound=-1000
GAPD.upper_bound=1000 

GAPD.add_metabolites({dpg_c: 1.0 , g3p_c: -1.0 , h_c: 1.0 , nad_c: -1.0 , nadh_c: 1.0 , pi_c: -1.0})        


#19
PGK=Reaction('PGK')
PGK.name='Phosphoglycerate_kinase'
PGK.lower_bound=-1000
PGK.upper_bound=1000

PGK.add_metabolites({dpg_c:1,adp_c:1,pg3_c:-1,atp_c:-1})  


#20
PGM=Reaction('PGM')
PGM.name='Phosphoglycerate_mutase'
PGM.lower_bound=-1000
PGM.upper_bound=1000

PGM.add_metabolites({pg3_c: 1 , pg2_c: -1})  



##21
ENO=Reaction('ENO')
ENO.name='Enolase'
ENO.lower_bound=-1000
ENO.upper_bound=1000

ENO.add_metabolites({pg2_c:-1,pep_c:1,h2o_c:1})

#22
PPS=Reaction('PPS')
PPS.name='Phosphoenolpyruvatesynthase'
PPS.lower_bound=0.0 
PPS.upper_bound=1000.0 

PPS.add_metabolites({amp_c:1.0,atp_c:-1.0,h2o_c:-1.0,h_c:2.0,pep_c:1.0,pi_c:1.0,pyr_c:-1.0})

#23
PYRt2=Reaction('PYRt2')
PYRt2.name='Pyruvate transport in via proton symport'
PYRt2.lower_bound=-1000.0 
PYRt2.upper_bound=1000.0 

PYRt2.add_metabolites({h_c:1.0,h_e:-1.0,pyr_c:1.0,pyr_e:-1.0})

#24
EX_pyr_e=Reaction('EX_pyr_e')
EX_pyr_e.name='Pyruvate exchange'
EX_pyr_e.lower_bound=0.0 
EX_pyr_e.upper_bound=1000.0 

EX_pyr_e.add_metabolites({pyr_e:-1.0})

#25
PPC=Reaction('PPC')
PPC.name='Phosphoenolpyruvate carboxylase'
PPC.lower_bound=0.0 
PPC.upper_bound=1000.0 

PPC.add_metabolites({co2_c: -1.0 , h2o_c: -1.0 , h_c: 1.0 , oaa_c: 1.0 , pep_c: -1.0 , pi_c: 1.0})


#26
PPCK=Reaction('PPCK')
PPCK.name='Phosphoenolpyruvate carboxykinase'
PPCK.lower_bound=0.0 
PPCK.upper_bound=1000.0     

PPCK.add_metabolites({adp_c:1.0,atp_c:-1.0,co2_c:1.0,oaa_c:-1.0,pep_c:1.0})


##27
PYK=Reaction('PYK')
PYK.name='PyruvateKinase'
PYK.lower_bound=0
PYK.upper_bound=1000
 
PYK.add_metabolites({adp_c: -1.0 , atp_c: 1.0 , h_c: -1.0 , pep_c: -1.0 , pyr_c: 1.0})  


##28
LDH_D=Reaction('LDH_D' )
LDH_D.name='Lactate_Dehydrogenase '
LDH_D.lower_bound=-1000
LDH_D.upper_bound=1000 

LDH_D.add_metabolites({h_c: 1.0 , lac__D_c: -1.0 , nad_c: -1.0 , nadh_c: 1.0 , pyr_c: 1.0})



#29
D_LACt2=Reaction('D_LACt2') 
D_LACt2.name='LactateExchange '
D_LACt2.lower_bound=-1000
D_LACt2.upper_bound=1000 

D_LACt2.add_metabolites({lac__D_e:-1,h_e:-1,h_c:1,lac__D_c:1})   

#30
EX_lac__D_e=Reaction('EX_lac__D_e') 
EX_lac__D_e.name='D-lactateexchange '
EX_lac__D_e.lower_bound=0
EX_lac__D_e.upper_bound=1000 
 

EX_lac__D_e.add_metabolites({lac__D_e: -1})  


 



############################################################################# Ractions    


#########   accoa_c:-1 + oaa_c:-1 + h2o_c:-1  ======>>  cit_c:1 + coa_c:1 +  h_c:1   
CS=Reaction("CS")
CS.name="Citrate synthase"
CS.lower_bound=0
CS.upper_bound=1000


CS.add_metabolites({accoa_c:-1 , oaa_c:-1 , h2o_c:-1 , cit_c:1 , coa_c:1 ,  h_c:1 })

######### cit_c:-1 <<============>>  acon_C_c:1 + h2o_c:1               

ACONTa=Reaction("ACONTa")
ACONTa.name="Aconitase"
ACONTa.lower_bound=-1000
ACONTa.upper_bound=1000


ACONTa.add_metabolites({cit_c:-1, acon_C_c:1,  h2o_c:1})

######### acon_C_c:-1 + h2o_c:-1 <<============>>  icit_c:1                               4
ACONTb=Reaction("ACONTb")
ACONTb.name="Aconitase"
ACONTb.lower_bound=-1000
ACONTb.upper_bound=1000


ACONTb.add_metabolites({ acon_C_c:-1,  h2o_c:-1,    icit_c:1})

######### icit_c:-1 + nadp_c:-1  <<============>>  nadph_c:1  +   akg_c:1   +     co2_c:1                                    5
ICDHyr=Reaction("ICDHyr")
ICDHyr.name="Isocitrate_dehydrogenas"
ICDHyr.lower_bound=-1000
ICDHyr.upper_bound=1000


ICDHyr.add_metabolites({icit_c:-1 , nadp_c:-1  ,  nadph_c:1  ,   akg_c:1   ,     co2_c:1 })

######### {akg_c:-1+ coa_c:-1+  nadp_c:-1  <<============>>  co2_c:1+ nadph_c:1+ succoa_c:1  
AKGDH=Reaction("AKGDH")
AKGDH.name="2-Oxogluterate_dehydrogenase"
AKGDH.lower_bound=0
AKGDH.upper_bound=1000


AKGDH.add_metabolites({akg_c:-1, coa_c:-1,  nad_c:-1,   co2_c:1, nadh_c:1, succoa_c:1 })

#########      atp_c:-1,coa_c:-1,  succ_c:-1 <<============>> succoa_c:1, adp_c:1 ,pi_c:1  مش متاكده منه                        
SUCOAS=Reaction("SUCOAS")
SUCOAS.name="Succinyl-CoA synthetase(ADP-forming)"
SUCOAS.lower_bound=-1000
SUCOAS.upper_bound=1000

SUCOAS.add_metabolites({ atp_c:-1,coa_c:-1,  succ_c:-1 , succoa_c:1, adp_c:1 ,pi_c:1 })

#########    q8_c:-1, succ_c:-1 <<============>>  fum_c:1,  q8h2_c:1                             
SUCDi=Reaction("SUCDi")
SUCDi.name="Succinate_dehydrogenase"
SUCDi.lower_bound=0
SUCDi.upper_bound=1000


SUCDi.add_metabolites({q8_c:-1, succ_c:-1,fum_c:1,  q8h2_c:1  })   

#########   fum_c:-1,  h2o_c:-1 <<============>>  mal__L_c:1
FUM=Reaction("FUM")
FUM.name="Fumarase"
FUM.lower_bound=-1000
FUM.upper_bound=1000

FUM.add_metabolites({  fum_c:-1,  h2o_c:-1, mal__L_c:1 })

#########    nadp_c:-1,  mal__L_c:-1  <<============>> h_c:1, nadph_c:1, oaa_c :1                  
MDH=Reaction("MDH")
MDH.name=("Malate_dehydrogenase")
MDH.lower_bound=-1000
MDH.upper_bound=1000


MDH.add_metabolites({  nad_c:-1,  mal__L_c:-1  ,h_c:1, nadh_c:1, oaa_c :1})

### NADH + Q + 5H+_{matrix}-> NAD+ + QH2 + 4H+_{intermembrane}
THD2= Reaction('THD2')
THD2.name = 'THD2'
THD2.lower_bound = 0
THD2.upper_bound = 1000

THD2.add_metabolites({ nadh_c : -1 , h_e: -2, nadp_c: -1 , nadph_c: 1 ,nad_c: 1 , h_c: 2 })


### NADH + Q + 5H+_{matrix}-> NAD+ + QH2 + 4H+_{intermembrane}
NADTRHD = Reaction('NADTRHD')
NADTRHD.name = 'NADTRHD'
NADTRHD.lower_bound = 0
NADTRHD.upper_bound = 1000

NADTRHD.add_metabolites({ nad_c : -1 , nadph_c: -1 ,nadh_c: 1 , nadp_c: 4})


### ADP + P_i + 4H+_{intermembrane} <=>  ATP + H2O + 4H+_{matrix}
ATPS4r = Reaction('ATPS4r')
ATPS4r.name = 'ATPS4r'
ATPS4r.lower_bound = -1000
ATPS4r.upper_bound = 1000

ATPS4r.add_metabolites({ h_e : -4 , adp_c: -1 ,pi_c: 1 , nadp_c: 4})

###############################
ATPM = Reaction('ATPM')
ATPM.name = 'ATPM'
ATPM.lower_bound = 0
ATPM.upper_bound = 1000

ATPM.add_metabolites({atp_c: -1, h2o_c: -1 ,h_c: 1, pi_c: 1 , adp_c: 1})

#################################
ADK1 = Reaction('ADK1')
ADK1.name = 'ADK1'
ADK1.lower_bound = -1000
ADK1.upper_bound = 1000

ADK1.add_metabolites({atp_c: -1 , amp_c: -1 ,adp_c: 2 })


#######################
O2t = Reaction('O2t')
O2t.name = 'O2t'
O2t.lower_bound = -1000
O2t.upper_bound = 1000

O2t.add_metabolites({o2_c:1.0, o2_e:-1.0 })


#######################
CYTBD = Reaction('CYTBD')
CYTBD.name = 'CYTBD'
CYTBD.lower_bound = 0
CYTBD.upper_bound = 1000

CYTBD.add_metabolites({h2o_c: 1.0 , h_c: -2.0 , h_e:2.0 , o2_c:-0.5, q8_c: 1.0 , q8h2_c: -1.0})



#####################################
SUCCt3 = Reaction('SUCCt3')
SUCCt3.name = 'SUCCt3'
SUCCt3.lower_bound = 0
SUCCt3.upper_bound = 1000

SUCCt3.add_metabolites({h_c: 1.0,
h_e: -1.0,
succ_c: -1.0,
succ_e: 1.0})


##########################
SUCCt2_2 = Reaction('SUCCt2_2')
SUCCt2_2.name = 'Succinate transport via proton symport (2 H)'
SUCCt2_2.lower_bound = 0
SUCCt2_2.upper_bound = 1000

SUCCt2_2.add_metabolites({
h_c: 2.0,
h_e: -2.0,
succ_c: 1.0,
succ_e: -1.0})

#####################################
EX_succ_e = Reaction('EX_succ_e')
EX_succ_e.name = 'Succinate exchange'
EX_succ_e.lower_bound = 0
EX_succ_e.upper_bound = 1000

EX_succ_e.add_metabolites({succ_e: -1.0})


##########################################
NADH16 = Reaction('NADH16')
NADH16.name = 'NADH16'
NADH16.lower_bound = 0
NADH16.upper_bound = 1000

NADH16.add_metabolites({h_c: -4.0 , nad_c: 1.0 , h_e: 3.0 , nadh_c: -1.0, q8_c: -1.0 , q8h2_c: 1.0})


######################################
AKGt2r = Reaction('AKGt2r')
AKGt2r.name = 'AKGt2r'
AKGt2r.lower_bound = -1000
AKGt2r.upper_bound = 1000

AKGt2r.add_metabolites({akg_c: 1.0 , akg_e: -1.0 , h_c: 1.0 , h_e: -1.0})


#######################################
GLUt2r = Reaction('GLUt2r')
GLUt2r.name = 'GLUt2r'
GLUt2r.lower_bound = -1000
GLUt2r.upper_bound = 1000

GLUt2r.add_metabolites({glu__L_c: 1.0 , glu__L_e: -1.0 , h_c: 1.0 , h_e: -1.0})

###############################
GLUDy = Reaction('GLUDy')
GLUDy.name = 'GLUDy'
GLUDy.lower_bound = -1000
GLUDy.upper_bound = 1000

GLUDy.add_metabolites({glu__L_c: -1.0 , akg_c: 1.0 , h2o_c:-1.0, h_c: 1.0, nadp_c: -1.0, nadph_c: 1.0, nh4_c: 1.0})

################################
GLUSy = Reaction('GLUSy')
GLUSy.name = 'GLUSy'
GLUSy.lower_bound = 0
GLUSy.upper_bound = 1000

GLUSy.add_metabolites({akg_c: -1.0 , gln__L_c: -1.0 , glu__L_c: 2.0 , h_c: -1.0 , nadp_c: 1.0 , nadph_c: -1.0})

################################

GLNS = Reaction('GLNS')
GLNS.name = 'GLNS'
GLNS.lower_bound = 0
GLNS.upper_bound = 1000

GLNS.add_metabolites({adp_c: 1.0 , atp_c: -1.0 , gln__L_c: 1.0 , glu__L_c: -1.0 , h_c: 1.0 , nh4_c: -1.0 , pi_c: 1.0})

###############################
GLUN = Reaction('GLUN')
GLUN.name = 'GLUN'
GLUN.lower_bound = 0
GLUN.upper_bound = 1000

GLUN.add_metabolites({ gln__L_c: -1.0 , glu__L_c: 1.0 , h2o_c: -1.0 , nh4_c: 1.0 })


################################

GLNabc = Reaction('GLNabc')
GLNabc.name = 'GLNabc'
GLNabc.lower_bound = 0
GLNabc.upper_bound = 1000

GLNabc.add_metabolites({ adp_c: 1.0 , atp_c: -1.0 , gln__L_c: 1.0 , gln__L_e: -1.0 , h2o_c: -1.0 , h_c: 1.0 , pi_c: 1.0 })


#################################

#------>Reactions<------#
 
PYK=Reaction('PYK')
PYK.name='PyruvateKinase'
PYK.lower_bound=0.0
PYK.upper_bound=1000

PYK.add_metabolites({adp_c:-1.0,atp_c:1.0,h_c:-1.0,pep_c:-1.0,pyr_c:1.0})

#
PFL=Reaction('PFL')  
PFL.name='Pyruvate formate lyase'
PFL.lower_bound=0.0
PFL.upper_bound=1000.0

PFL.add_metabolites({accoa_c:1.0,coa_c:-1.0,for_c:1.0,pyr_c:-1.0})

#
FORti=Reaction('FORti')  
FORti.name='Formate transport via diffusion'
FORti.lower_bound=-1000.0  
FORti.upper_bound=0.0

FORti.add_metabolites({for_c:1.0,for_e:-1.0})
 

#
FORt2=Reaction('FORt2')  
FORt2.name='Formate transport in via proton symport'
FORt2.lower_bound=0.0  
FORt2.upper_bound=1000.0

FORt2.add_metabolites({for_c:1.0,for_e:-1.0,h_c:1.0,h_e:-1.0})


#
EX_for_e=Reaction('EX_for_e')  
EX_for_e.name='Formate exchange'
EX_for_e.lower_bound=0.0  
EX_for_e.upper_bound=1000.0 

EX_for_e.add_metabolites({for_e:-1.0})

#pyruvate to acetal coenzyme A by Pyruvate dehydrogenase(PDH)
PDH=Reaction('PDH')  
PDH.name='Pyruvate dehydrogenase'
PDH.lower_bound= 0.0
PDH.upper_bound=1000 

PDH.add_metabolites({accoa_c:1.0,co2_c:1.0,coa_c:-1.0,nad_c:-1.0,nadh_c:1.0,pyr_c:-1.0}) 

#
PTAr=Reaction('PTAr')  
PTAr.name='Phosphotransacetylase'
PTAr.lower_bound=-1000.0  
PTAr.upper_bound=1000.0

PTAr.add_metabolites({accoa_c:-1.0,actp_c:1.0,coa_c:1.0,pi_c:-1.0})

#
ACKr=Reaction('ACKr')  
ACKr.name='Acetate kinase'
ACKr.lower_bound=-1000.0  
ACKr.upper_bound=1000.0 

ACKr.add_metabolites({ac_c:-1.0,actp_c:1.0,adp_c:1.0,atp_c:-1.0})

#
ACt2r=Reaction('ACt2r')  
ACt2r.name='Acetate reversible transport via proton symport'
ACt2r.lower_bound=-1000.0  
ACt2r.upper_bound=1000.0 

ACt2r.add_metabolites({ac_c:1.0,ac_e:-1.0,h_c:1.0,h_e:-1.0})

#
EX_ac_e=Reaction('EX_ac_e')  
EX_ac_e.name='Acetate exchange'
EX_ac_e.lower_bound=0.0  
EX_ac_e.upper_bound=1000.0

EX_ac_e.add_metabolites({ac_e:-1.0})

 
##ethanol is formed by the reduction of acetal coenzyme A using NADH in two steps:
#acetal-COA to acetaldehyde byAcetaldehyde dehydrogenase( Acetaldehyde dehydrogenase)
ACALD=Reaction('ACALD') #acetal-COA + NADH + H+ ----->acetaldehyde + NAD+ + COA  
ACALD.name='Acetaldehyde dehydrogenase '
ACALD.lower_bound=-1000
ACALD.upper_bound=1000

ACALD.add_metabolites({acald_c:-1.0,accoa_c:1.0,coa_c:-1.0,h_c:1.0,nad_c:-1.0,nadh_c:1.0})

#
ACALDt=Reaction('ACALDt')  
ACALDt.name='Acetaldehyde reversible transport'
ACALDt.lower_bound=-1000.0  
ACALDt.upper_bound=1000.0

ACALDt.add_metabolites({acald_c:1.0,acald_e:-1.0})

#
EX_acald_e=Reaction('EX_acald_e')  
EX_acald_e.name='Acetaldehyde exchange'
EX_acald_e.lower_bound=0.0  
EX_acald_e.upper_bound=1000.0 

EX_acald_e.add_metabolites({acald_e:-1.0})

# acetaldehyde to ethanol by alcohol dehydrogenase enzyme(ALCD2x )
ALCD2x=Reaction('ALCD2x') #acetaldehyde + NADH + H+  <----->ethanol + NAD+  
ALCD2x.name=' alcohol dehydrogenase'
ALCD2x.lower_bound=-1000
ALCD2x.upper_bound=1000

ALCD2x.add_metabolites({acald_c:1.0,etoh_c:-1.0,h_c:1.0,nad_c:-1.0,nadh_c:1.0})

#
ETOHt2r=Reaction('ETOHt2r')  
ETOHt2r.name='Ethanol reversible transport via proton symport'
ETOHt2r.lower_bound=-1000.0  
ETOHt2r.upper_bound=1000.0 

ETOHt2r.add_metabolites({etoh_c:1.0,etoh_e:-1.0,h_c:1.0,h_e:-1.0})

#
EX_etoh_e=Reaction('EX_etoh_e')  
EX_etoh_e.name='Ethanol exchange'
EX_etoh_e.lower_bound=0.0  
EX_etoh_e.upper_bound=1000.0 
 
EX_etoh_e.add_metabolites({etoh_e:-1.0}) 

#######################################


ME1=Reaction('ME1')  
ME1.name='ME1'
ME1.lower_bound=0.0  
ME1.upper_bound=1000.0 
 
ME1.add_metabolites({co2_c: 1.0 , mal__L_c: -1.0 , nad_c: -1.0 , nadh_c: 1.0 , pyr_c: 1.0}) 
#########################


ME2=Reaction('ME2')  
ME2.name='ME2'
ME2.lower_bound=0.0  
ME2.upper_bound=1000.0 
 
ME2.add_metabolites({co2_c: 1.0 , mal__L_c: -1.0 , nadp_c: -1.0 , nadph_c: 1.0 , pyr_c: 1.0}) 

########################
MALS=Reaction('MALS')  
MALS.name='MALS'
MALS.lower_bound=0.0  
MALS.upper_bound=1000.0 
 
MALS.add_metabolites({accoa_c: -1.0 , coa_c: 1.0 , glx_c: -1.0 , h2o_c: -1.0 , h_c: 1.0 , mal__L_c: 1.0}) 


########################
ICL=Reaction('ICL')  
ICL.name='ICL'
ICL.lower_bound=0.0  
ICL.upper_bound=1000.0 
 
ICL.add_metabolites({glx_c: 1.0 , icit_c: -1.0 , succ_c: 1.0}) 

######################
PIt2r=Reaction('PIt2r')  
PIt2r.name='PIt2r'
PIt2r.lower_bound=-1000.0  
PIt2r.upper_bound=1000.0 
 
PIt2r.add_metabolites({h_c: 1.0 , h_e: -1.0 , pi_c: 1.0 , pi_e: -1.0}) 

###################

EX_pi_e=Reaction('EX_pi_e')  
EX_pi_e.name='EX_pi_e'
EX_pi_e.lower_bound=-1000.0  
EX_pi_e.upper_bound=1000.0 
 
EX_pi_e.add_metabolites({pi_e: -1.0}) 

################
H2Ot=Reaction('H2Ot')  
H2Ot.name='H2Ot'
H2Ot.lower_bound=-1000.0  
H2Ot.upper_bound=1000.0 
 
H2Ot.add_metabolites({h2o_c: 1.0 , h2o_e: -1.0}) 

###################
EX_h2o_e=Reaction('EX_h2o_e')  
EX_h2o_e.name='EX_h2o_e'
EX_h2o_e.lower_bound=-1000.0  
EX_h2o_e.upper_bound=1000.0 
 
EX_h2o_e.add_metabolites({h2o_e: -1.0}) 

#####################
###################
CO2t=Reaction('CO2t')  
CO2t.name='CO2t'
CO2t.lower_bound=-1000.0  
CO2t.upper_bound=1000.0 
 
CO2t.add_metabolites({co2_c: 1.0 , co2_e: -1.0}) 

#############################
EX_co2_e=Reaction('EX_co2_e')  
EX_co2_e.name='EX_co2_e'
EX_co2_e.lower_bound=-1000.0  
EX_co2_e.upper_bound=1000.0 
 
EX_co2_e.add_metabolites({co2_e: -1.0}) 

#####################
NH4t=Reaction('NH4t')  
NH4t.name='NH4t'
NH4t.lower_bound=-1000.0  
NH4t.upper_bound=1000.0 
 
NH4t.add_metabolites({nh4_c: 1.0 , nh4_e: -1.0}) 


#####################
EX_nh4_e=Reaction('EX_nh4_e')  
EX_nh4_e.name='EX_nh4_e'
EX_nh4_e.lower_bound=-1000.0  
EX_nh4_e.upper_bound=1000.0 
 
EX_nh4_e.add_metabolites({ nh4_e: -1.0}) 

###########




#######################
BIOMASS_Ecoli_core_w_GAM = Reaction('BIOMASS_Ecoli_core_w_GAM')
BIOMASS_Ecoli_core_w_GAM.name = 'BIOMASS_Ecoli_core_w_GAM'
BIOMASS_Ecoli_core_w_GAM.lower_bound = 0
BIOMASS_Ecoli_core_w_GAM.upper_bound = 1000

BIOMASS_Ecoli_core_w_GAM.add_metabolites({
pg_c: -1.496 , 
accoa_c: -3.7478, 
adp_c: 59.81, 
akg_c: 4.1182, 
atp_c: -59.81 ,
coa_c: 3.7478 ,
e4p_c: -0.361 ,
f6p_c: -0.0709,
g3p_c: -0.129,
g6p_c: -0.205,
gln__L_c: -0.2557,
glu__L_c: -4.9414,
h2o_c: -59.81,
h_c: 59.81,
nad_c: -3.547,
nadh_c: 3.547,
nadp_c: 13.0279,
nadph_c: -13.0279,
oaa_c: -1.7867,
pep_c: -0.5191,
pi_c: 59.81,
pyr_c: -2.8328,
r5p_c: -0.8977})

# %%
EX_gln__L_e=Reaction('EX_gln__L_e')  
EX_gln__L_e.name='EX_gln__L_e'
EX_gln__L_e.lower_bound=0.0  
EX_gln__L_e.upper_bound=1000.0 
 
EX_gln__L_e.add_metabolites({ gln__L_e: -1.0}) 

#########################

EX_glu__L_e=Reaction('EX_glu__L_e')  
EX_glu__L_e.name='EX_glu__L_e'
EX_glu__L_e.lower_bound=0.0  
EX_glu__L_e.upper_bound=1000.0 
 
EX_glu__L_e.add_metabolites({ glu__L_e: -1.0}) 

############################
EX_akg_e=Reaction('EX_akg_e')  
EX_akg_e.name='EX_akg_e'
EX_akg_e.lower_bound=0.0  
EX_akg_e.upper_bound=1000.0 
 
EX_akg_e.add_metabolites({ akg_e: -1.0}) 


##################
EX_h_e=Reaction('EX_h_e')  
EX_h_e.name='EX_h_e'
EX_h_e.lower_bound= -1000.0  
EX_h_e.upper_bound=1000.0 
 
EX_h_e.add_metabolites({ h_e: -1.0}) 


########################
EX_o2_e=Reaction('EX_o2_e')  
EX_o2_e.name='EX_o2_e'
EX_o2_e.lower_bound= -1000.0  
EX_o2_e.upper_bound=1000.0 
 
EX_o2_e.add_metabolites({ o2_e: -1.0})

# %%
model.add_reactions({EX_lac__D_e , D_LACt2 , LDH_D , PYK , PPCK , PPC , EX_pyr_e , PYRt2 
                     , PPS , ENO , PGM , PGK , GAPD , FBA , TPI , FBP , PFK , EX_fru_e , 
                     FRUpts2 , PGI ,TKT2 ,TALA ,TKT1 , RPI , RPE , GND , PGL , G6PDH2r 
                     , GLCpts , EX_glc__D_e, CS , ACONTa , ACONTb , ICDHyr , AKGDH,SUCOAS,SUCDi,
                     FUM , MDH ,THD2 , NADTRHD , ATPS4r ,ATPM , ADK1 ,O2t ,CYTBD , NADH16
                     , SUCCt3 ,SUCCt2_2 , EX_succ_e ,AKGt2r , GLNabc , GLUN , GLNS , GLUSy
                     , GLUDy , GLUt2r ,PYK, PFL , FORti , FORt2 , EX_for_e , PDH , PTAr ,
                     ACKr , ACt2r , EX_ac_e , ACALD , ACALDt , EX_acald_e , ALCD2x ,
                     ETOHt2r , EX_etoh_e , BIOMASS_Ecoli_core_w_GAM , EX_nh4_e ,NH4t ,EX_co2_e ,CO2t ,
                     EX_h2o_e ,H2Ot , EX_pi_e, PIt2r ,ICL ,MALS ,EX_glu__L_e ,EX_akg_e ,EX_h_e
                     ,ME2 ,ME1 ,EX_etoh_e ,EX_gln__L_e ,EX_o2_e })



##73

# %%
cobra.io.save_json_model(model,"yayayayya.json")

# %%
cobra.io.load_json_model("yayayayya.json")


#### === model
# Out:
# <Model FULL at 0x1c39dc213d0>

# %%
#import cobra.test
#cobra.test.create_test_model("yayayayya")

# %%
model.objective = 'BIOMASS_Ecoli_core_w_GAM'

# %%
model.optimize()
model.optimize().objective_value
# Out:
# 0.47355884205391957

# %%
print(model.objective.expression)
print(model.objective.direction)
# Out:
# 1.0*BIOMASS_Ecoli_core_w_GAM - 1.0*BIOMASS_Ecoli_core_w_GAM_reverse_712e5
# max

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli_core_w_GAM = 0.47355884205391974</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>co2_e</td>
#       <td>EX_co2_e</td>
#       <td>0.8461</td>
#       <td>1</td>
#       <td>1.39%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>98.61%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>2.582</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>6.151</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>1.742</td>
#       <td>0</td>
# ...

# %%
from escher import Builder
builder=Builder()

# %%
builder
# Out:
# Builder()

# %%
sol= model.optimize()
builder.reaction_data =sol.fluxes
